# %% [markdown]
# # Installation and Loading

# %%
pip install pandas

# %%
import os
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls "/content/drive/My Drive/Colab Notebooks"
# Out:
#  data_modified.json               Numpy.ipynb
#  ETH_1h.csv                       numpy.txt
#  Leet_code.ipynb                  pandas.ipynb
# 'longest substring3.ipynb'        problem.ipynb
#  Minimum_path_sum_leet_64.ipynb   survey_results_public.csv
#  modified.json                    survey_results_schema.csv

# %%
os.chdir("/content/drive/My Drive/Colab Notebooks")

# %%
df = pd.read_csv("survey_results_public.csv")
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
schema_df = pd.read_csv("survey_results_schema.csv")
schema_df.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %% [markdown]
# # Accessing rows and columns

# %%
pd.set_option("display.max_columns",85)
pd.set_option("display.max_rows",85)
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
people = {"first":["corey","jan","jon"],
          "last":["schafer","Doe","Doe"],
          "email":["corey@gmail.com","jan@gmail.com","jon@gmail.com"]}

# %%
df1 = pd.DataFrame(people)
df1
# Out:
#    first     last            email
# 0  corey  schafer  corey@gmail.com
# 1    jan      Doe    jan@gmail.com
# 2    jon      Doe    jon@gmail.com

# %%
type(df1["email"])
# Out:
# pandas.core.series.Series

# %%
df1.email
# Out:
# 0    corey@gmail.com
# 1      jan@gmail.com
# 2      jon@gmail.com
# Name: email, dtype: object

# %%
df1["email"]
# Out:
# 0    corey@gmail.com
# 1      jan@gmail.com
# 2      jon@gmail.com
# Name: email, dtype: object

# %%
df1.count()
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df1[["first","email"]]
# Out:
#    first            email
# 0  corey  corey@gmail.com
# 1    jan    jan@gmail.com
# 2    jon    jon@gmail.com

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df1.iloc[[0,1,2],2]
# Out:
# 0    corey@gmail.com
# 1      jan@gmail.com
# 2      jon@gmail.com
# Name: email, dtype: object

# %%
df1.loc[[0,1,2],"email"]
# Out:
# 0    corey@gmail.com
# 1      jan@gmail.com
# 2      jon@gmail.com
# Name: email, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df["MainBranch"]
# Out:
# 0                         None of these
# 1        I am a developer by profession
# 2        I am a developer by profession
# 3        I am a developer by profession
# 4        I am a developer by profession
#                       ...
# 89179    I am a developer by profession
# 89180    I am a developer by profession
# 89181       I code primarily as a hobby
# 89182    I am a developer by profession
# 89183    I am a developer by profession
# Name: MainBranch, Length: 89184, dtype: object

# %%
df.loc[0:2,"ResponseId":"RemoteWork"]
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
#
#             Employment                            RemoteWork
# 0                  NaN                                   NaN
# 1  Employed, full-time                                Remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)

# %% [markdown]
# # Set,Reset,Use Indexes

# %%
df1.set_index("email",inplace=True)
df1
# Out:
#                  first     last
# email
# corey@gmail.com  corey  schafer
# jan@gmail.com      jan      Doe
# jon@gmail.com      jon      Doe

# %%
df1.index
# Out:
# Index(['corey@gmail.com', 'jan@gmail.com', 'jon@gmail.com'], dtype='object', name='email')

# %%
df1.loc["corey@gmail.com","last"]
# Out:
# 'schafer'

# %%
df1.iloc[0]
# Out:
# first      corey
# last     schafer
# Name: corey@gmail.com, dtype: object

# %%
df1.reset_index(inplace=True)
df1
# Out:
#              email  first     last
# 0  corey@gmail.com  corey  schafer
# 1    jan@gmail.com    jan      Doe
# 2    jon@gmail.com    jon      Doe

# %% [markdown]
# # Filter rows and columns

# %%
filt = ((df1["first"]=="jon") & (df1["last"]=="Doe"))

# %%
df1.loc[filt,"email"]
# Out:
# 2    jon@gmail.com
# Name: email, dtype: object

# %%
df1.loc[~filt,"email"]
# Out:
# 0    corey@gmail.com
# 1      jan@gmail.com
# Name: email, dtype: object

# %%
High_salary = (df["CompTotal"]>70000)

# %%
df.loc[High_salary]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 1               2  I agree  I am a developer by profession  25-34 years old
# 2               3  I agree  I am a developer by profession  45-54 years old
# 3               4  I agree  I am a developer by profession  25-34 years old
# 4               5  I agree  I am a developer by profession  25-34 years old
# 5               6  I agree  I am a developer by profession  35-44 years old
# ...           ...      ...                             ...              ...
# 89175       89176  I agree  I am a developer by profession  25-34 years old
# 89177       89178  I agree  I am a developer by profession  35-44 years old
# 89178       89179  I agree  I am a developer by profession  45-54 years old
# 89179       89180  I agree  I am a developer by profession  25-34 years old
# 89183       89184  I agree  I am a developer by profession  35-44 years old
#
# ...

# %%
df.loc[High_salary,["Country","LanguageWantToWorkWith","CompTotal"]]
# Out:
#                                                  Country  \
# 1                               United States of America
# 2                               United States of America
# 3                               United States of America
# 4                                            Philippines
# 5      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 89175                           United States of America
# 89177                                             Mexico
# 89178                           United States of America
# 89179                                             Brazil
# 89183                       Iran, Islamic Republic of...
#
#                                   LanguageWantToWorkWith     CompTotal
# 1      Bash/Shell (all shells);C#;Dart;Elixir;GDScrip...  2.850000e+05
# 2                                     Haskell;OCaml;Rust  2.500000e+05
# ...

# %%
countries=["Brazil","Mexico"]
filt = df["Country"].isin(countries)
df.loc[filt,["Country","CompTotal"]]
# Out:
#       Country  CompTotal
# 31     Brazil   130000.0
# 88     Brazil   120000.0
# 104    Brazil        NaN
# 107    Brazil    92000.0
# 250    Brazil   150000.0
# ...       ...        ...
# 89149  Brazil        NaN
# 89160  Mexico   500000.0
# 89162  Brazil   250000.0
# 89177  Mexico  1000000.0
# 89179  Brazil   200000.0
#
# [2647 rows x 2 columns]

# %%
filt = df["LanguageWantToWorkWith"].str.contains("Python",na=False)

# %%
df.loc[filt,["LanguageWantToWorkWith","LanguageHaveWorkedWith"]]
# Out:
#                                   LanguageWantToWorkWith  \
# 4             HTML/CSS;JavaScript;Python;Rust;TypeScript
# 7      Elixir;Go;Julia;Python;R;Rust;Scala;SQL;TypeSc...
# 10                                                Python
# 13                         Assembly;C;C++;Go;Python;Rust
# 21     Bash/Shell (all shells);Delphi;PHP;Python;Rust...
# ...                                                  ...
# 89166                               C#;Python;TypeScript
# 89178                    Go;JavaScript;Python;TypeScript
# 89180              Java;JavaScript;Python;SQL;TypeScript
# 89181                                        Python;Rust
# 89182  Bash/Shell (all shells);HTML/CSS;JavaScript;Po...
#
#                                   LanguageHaveWorkedWith
# 4                         HTML/CSS;JavaScript;TypeScript
# 7      Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10                     C#;C++;HTML/CSS;JavaScript;Python
# ...

# %% [markdown]
# # Updating rows and columns

# %%
df1.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
df1.columns = ["Email","First name","Last name"] #column rename
df1
# Out:
#              Email First name Last name
# 0  corey@gmail.com      corey   schafer
# 1    jan@gmail.com        jan       Doe
# 2    jon@gmail.com        jon       Doe

# %%
df1.columns = [x.upper() for x in df1.columns]
df1
# Out:
#              EMAIL FIRST NAME LAST NAME
# 0  corey@gmail.com      corey   schafer
# 1    jan@gmail.com        jan       Doe
# 2    jon@gmail.com        jon       Doe

# %%
df1.columns = df1.columns.str.replace(' ','_')
df1
# Out:
#              EMAIL FIRST_NAME LAST_NAME
# 0  corey@gmail.com      corey   schafer
# 1    jan@gmail.com        jan       Doe
# 2    jon@gmail.com        jon       Doe

# %%
df1.rename(columns = {"FIRST_NAME":"first","LAST_NAME":"last"})
# Out:
#              EMAIL  first     last
# 0  corey@gmail.com  corey  schafer
# 1    jan@gmail.com    jan      Doe
# 2    jon@gmail.com    jon      Doe

# %%
df1
# Out:
#              EMAIL FIRST_NAME LAST_NAME
# 0  corey@gmail.com      corey   schafer
# 1    jan@gmail.com        jan       Doe
# 2    jon@gmail.com        jon       Doe

# %%
df1.rename(columns = {"FIRST_NAME":"first","LAST_NAME":"last"},inplace = True)

# %%
df1
# Out:
#              EMAIL  first     last
# 0  corey@gmail.com  corey  schafer
# 1    jan@gmail.com    jan      Doe
# 2    jon@gmail.com    jon      Doe

# %%
df1.loc[2]
# Out:
# EMAIL    jon@gmail.com
# first              jon
# last               Doe
# Name: 2, dtype: object

# %%
df1.loc[2] = ["johnsmith@gmail.com","jon","smith"]
df1
# Out:
#                  EMAIL  first     last
# 0      corey@gmail.com  corey  schafer
# 1        jan@gmail.com    jan      Doe
# 2  johnsmith@gmail.com    jon    smith

# %%
df1.iloc[:,[0]]
# Out:
#                  EMAIL
# 0      corey@gmail.com
# 1        jan@gmail.com
# 2  johnsmith@gmail.com

# %%
df1.loc[2,["last","EMAIL"]] = ["Doe","johndoe@gmail.com"]
df1
# Out:
#                EMAIL  first     last
# 0    corey@gmail.com  corey  schafer
# 1      jan@gmail.com    jan      Doe
# 2  johndoe@gmail.com    jon      Doe

# %%
df1.loc[2,"last"] = "smith"
df1
# Out:
#                EMAIL  first     last
# 0    corey@gmail.com  corey  schafer
# 1      jan@gmail.com    jan      Doe
# 2  johndoe@gmail.com    jon    smith

# %%
df1["EMAIL"].apply(len)
# Out:
# 0    15
# 1    13
# 2    17
# Name: EMAIL, dtype: int64

# %%
df1.apply(len,axis="columns" )
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df1["EMAIL"])
# Out:
# 3

# %%
df1.apply(pd.Series.min)
# Out:
# EMAIL    corey@gmail.com
# first              corey
# last                 Doe
# dtype: object

# %%
df1.apply(lambda x: x.min())
# Out:
# EMAIL    corey@gmail.com
# first              corey
# last                 Doe
# dtype: object

# %%
df1.applymap(len) # every column items length
# Out:
#    EMAIL  first  last
# 0     15      5     7
# 1     13      3     3
# 2     17      3     5

# %%
df1.loc[2,"last"] = "doe"
df1
# Out:
#                EMAIL  first     last
# 0    corey@gmail.com  corey  schafer
# 1      jan@gmail.com    jan      Doe
# 2  johndoe@gmail.com    jon      doe

# %%
df1.applymap(str.lower)
# Out:
#                EMAIL  first     last
# 0    corey@gmail.com  corey  schafer
# 1      jan@gmail.com    jan      doe
# 2  johndoe@gmail.com    jon      doe

# %%
df1["first"].map({"corey":"chris","jan":"mary"})
# Out:
# 0    chris
# 1     mary
# 2      NaN
# Name: first, dtype: object

# %%
df1["first"] = df1["first"].replace({"corey":"chris","jan":"mary"})
df1
# Out:
#                EMAIL  first     last
# 0    corey@gmail.com  chris  schafer
# 1      jan@gmail.com   mary      Doe
# 2  johndoe@gmail.com    jon      doe

# %%
df1.rename(columns = {"EMAIL":"Email"},inplace=True)
df1
# Out:
#                Email  first     last
# 0    corey@gmail.com  chris  schafer
# 1      jan@gmail.com   mary      Doe
# 2  johndoe@gmail.com    jon      doe

# %%
df["SOAccount"]
# Out:
# 0        NaN
# 1        Yes
# 2        Yes
# 3        Yes
# 4         No
#         ...
# 89179    Yes
# 89180    Yes
# 89181    NaN
# 89182     No
# 89183    Yes
# Name: SOAccount, Length: 89184, dtype: object

# %%
df["SOAccount"] = df["SOAccount"].map({"Yes":"True","No":"False"})

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %% [markdown]
# # Add/Remove rows and columns

# %%
df1
# Out:
#                Email  first     last
# 0    corey@gmail.com  chris  schafer
# 1      jan@gmail.com   mary      Doe
# 2  johndoe@gmail.com    jon      doe

# %%
df1["first"] + " " + df1["last"]
# Out:
# 0    chris schafer
# 1         mary Doe
# 2          jon doe
# dtype: object

# %%
df1["full name"] = df1["first"] + " " + df1["last"] #column adding
df1
# Out:
#                Email  first     last      full name
# 0    corey@gmail.com  chris  schafer  chris schafer
# 1      jan@gmail.com   mary      Doe       mary Doe
# 2  johndoe@gmail.com    jon      doe        jon doe

# %%
df1.drop(columns=["first","last"],inplace=True) #column deleting
df1
# Out:
#                Email      full name
# 0    corey@gmail.com  chris schafer
# 1      jan@gmail.com       mary Doe
# 2  johndoe@gmail.com        jon doe

# %%
df1["full name"].str.split(" ",expand=True)
# Out:
#        0        1
# 0  chris  schafer
# 1   mary      Doe
# 2    jon      doe

# %%
df1.append({"full name":"Tony"}, ignore_index=True)
# Out:
# <ipython-input-364-790eacb2a61e>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append({"full name":"Tony"}, ignore_index=True)
#                Email      full name
# 0    corey@gmail.com  chris schafer
# 1      jan@gmail.com       mary Doe
# 2  johndoe@gmail.com        jon doe
# 3                NaN           Tony

# %%
people = {"first":["corey","jan","jon"],
          "last":["schafer","Doe","Doe"],
          "email":["corey@gmail.com","jan@gmail.com","jon@gmail.com"]}
df1 = pd.DataFrame(people)
df1
# Out:
#    first     last            email
# 0  corey  schafer  corey@gmail.com
# 1    jan      Doe    jan@gmail.com
# 2    jon      Doe    jon@gmail.com

# %%
people = {"first":["Tony","Steve"],
          "last":["stark","rogers"],
          "email":["Ironman@avenge.com","cap@avenge.com"]}
df2 = pd.DataFrame(people)
df2
# Out:
#    first    last               email
# 0   Tony   stark  Ironman@avenge.com
# 1  Steve  rogers      cap@avenge.com

# %%
df3 = df1.append(df2, ignore_index=True, sort=False)
df3
# Out:
# <ipython-input-367-0d49289492e3>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df1.append(df2, ignore_index=True, sort=False)
#    first     last               email
# 0  corey  schafer     corey@gmail.com
# 1    jan      Doe       jan@gmail.com
# 2    jon      Doe       jon@gmail.com
# 3   Tony    stark  Ironman@avenge.com
# 4  Steve   rogers      cap@avenge.com

# %%
df3.drop(index=4)
# Out:
#    first     last               email
# 0  corey  schafer     corey@gmail.com
# 1    jan      Doe       jan@gmail.com
# 2    jon      Doe       jon@gmail.com
# 3   Tony    stark  Ironman@avenge.com

# %%
filt = df3["last"] == "rogers"
df3.drop(index=df3[filt].index)
# Out:
#    first     last               email
# 0  corey  schafer     corey@gmail.com
# 1    jan      Doe       jan@gmail.com
# 2    jon      Doe       jon@gmail.com
# 3   Tony    stark  Ironman@avenge.com

# %% [markdown]
# # Sorting

# %%
df3.sort_values(by='last',ascending=False)
# Out:
#    first     last               email
# 3   Tony    stark  Ironman@avenge.com
# 0  corey  schafer     corey@gmail.com
# 4  Steve   rogers      cap@avenge.com
# 1    jan      Doe       jan@gmail.com
# 2    jon      Doe       jon@gmail.com

# %%
df3.sort_values(by=["last","first"],ascending=True)
# Out:
#    first     last               email
# 1    jan      Doe       jan@gmail.com
# 2    jon      Doe       jon@gmail.com
# 4  Steve   rogers      cap@avenge.com
# 0  corey  schafer     corey@gmail.com
# 3   Tony    stark  Ironman@avenge.com

# %%
df3.sort_index()
# Out:
#    first     last               email
# 0  corey  schafer     corey@gmail.com
# 1    jan      Doe       jan@gmail.com
# 2    jon      Doe       jon@gmail.com
# 3   Tony    stark  Ironman@avenge.com
# 4  Steve   rogers      cap@avenge.com

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df["Country"].unique()
# Out:
# array([nan, 'United States of America', 'Philippines',
#        'United Kingdom of Great Britain and Northern Ireland', 'Finland',
#        'India', 'Australia', 'Netherlands', 'Germany', 'Sweden', 'France',
#        'Albania', 'Nigeria', 'Spain', 'South Africa', 'Belgium', 'Italy',
#        'Brazil', 'Portugal', 'Bangladesh', 'Canada', 'Argentina',
#        'Switzerland', 'Sri Lanka', 'Poland', 'Lebanon', 'Lithuania',
#        'Serbia', 'Cyprus', 'China', 'Bahrain',
#        'Iran, Islamic Republic of...', 'Pakistan', 'Egypt',
#        'Russian Federation', 'Turkey', 'Slovakia', 'Latvia', 'Greece',
#        'Austria', 'Denmark', 'Israel', 'Norway', 'Hungary', 'Singapore',
#        'United Arab Emirates', 'Croatia', 'Czech Republic', 'Kosovo',
#        'Nepal', 'Slovenia', 'Romania', 'Luxembourg', 'Indonesia',
#        'Tunisia', 'Republic of Korea', 'Viet Nam', 'Ukraine', 'Kenya',
#        'Nomadic', 'Dominican Republic', 'Morocco', 'Uzbekistan',
# ...

# %%
df.sort_values(by="Country",inplace=True)
df["Country"].head()
# Out:
# 21497    Afghanistan
# 65292    Afghanistan
# 1334     Afghanistan
# 33927    Afghanistan
# 77722    Afghanistan
# Name: Country, dtype: object

# %%
df.sort_values(by=["Country","CompTotal"],ascending=True,inplace=True)

# %%
df[['Country','CompTotal']].head()
# Out:
#            Country  CompTotal
# 67793  Afghanistan        0.0
# 59005  Afghanistan        0.0
# 61075  Afghanistan        1.0
# 2641   Afghanistan      123.0
# 37955  Afghanistan     3600.0

# %%
df["CompTotal"].nlargest(10)
# Out:
# 56322    5.000000e+46
# 18463    1.000000e+21
# 43556    1.000000e+16
# 49553    1.000000e+16
# 35779    1.000000e+15
# 15439    4.567887e+12
# 33078    1.000000e+11
# 19679    2.239672e+10
# 56853    1.980000e+10
# 9175     1.840199e+10
# Name: CompTotal, dtype: float64

# %%
df.nlargest(5,"CompTotal")
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 56322       56323  I agree                     I am a developer by profession
# 18463       18464  I agree                     I am a developer by profession
# 43556       43557  I agree                     I am a developer by profession
# 49553       49554  I agree  I am not primarily a developer, but I write co...
# 35779       35780  I agree                     I am a developer by profession
#
#                    Age           Employment RemoteWork  \
# 56322  25-34 years old  Employed, full-time  In-person
# 18463  25-34 years old  Employed, full-time  In-person
# 43556  18-24 years old  Employed, full-time     Remote
# 49553  25-34 years old  Employed, full-time  In-person
# 35779  25-34 years old  I prefer not to say        NaN
#
#                                         CodingActivities  \
# 56322  Hobby;Contribute to open-source projects;Boots...
# ...

# %% [markdown]
# # Grouping and Aggregating

# %%
df["CompTotal"].head(5)
# Out:
# 67793       0.0
# 59005       0.0
# 61075       1.0
# 2641      123.0
# 37955    3600.0
# Name: CompTotal, dtype: float64

# %%
df["CompTotal"].median()
# Out:
# 115000.0

# %%
df.median()
# Out:
# <ipython-input-382-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# ResponseId              44592.5
# CompTotal              115000.0
# WorkExp                     9.0
# ConvertedCompYearly     74963.0
# dtype: float64

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
df["ConvertedCompYearly"].count()
# Out:
# 48019

# %%
df["SOAccount"].value_counts()
# Out:
# True     66282
# False    14618
# Name: SOAccount, dtype: int64

# %%
df["Country"].value_counts()
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 185, dtype: int64

# %%
country_grp = df.groupby(["Country"])
print(country_grp)

# %%
country_grp.get_group('Germany').head(5)
# Out:
#        ResponseId     Q120                      MainBranch                Age  \
# 33028       33029  I agree  I am a developer by profession    25-34 years old
# 45071       45072  I agree  I am a developer by profession    18-24 years old
# 30065       30066  I agree  I am a developer by profession    55-64 years old
# 30054       30055  I agree  I am a developer by profession    18-24 years old
# 28915       28916  I agree  I am a developer by profession  65 years or older
#
#                                               Employment  \
# 33028  Independent contractor, freelancer, or self-em...
# 45071  Employed, full-time;Independent contractor, fr...
# 30065                                Employed, full-time
# 30054  Independent contractor, freelancer, or self-em...
# 28915  Employed, full-time;Independent contractor, fr...
#
#                                  RemoteWork  \
# 33028                             In-person
# 45071                             In-person
# ...

# %%
country_grp['RemoteWork'].value_counts().head(10)
# Out:
# Country      RemoteWork
# Afghanistan  Hybrid (some remote, some in-person)    17
#              Remote                                  17
#              In-person                                8
# Albania      Hybrid (some remote, some in-person)    18
#              In-person                               17
#              Remote                                  15
# Algeria      Remote                                  27
#              Hybrid (some remote, some in-person)    12
#              In-person                               11
# Andorra      In-person                                6
# Name: RemoteWork, dtype: int64

# %%
country_grp['Industry'].value_counts().loc["Germany"]
# Out:
# Industry
# Information Services, IT, Software Development, or other Technology    1500
# Manufacturing, Transportation, or Supply Chain                          350
# Other                                                                   326
# Financial Services                                                      186
# Retail and Consumer Services                                            163
# Healthcare                                                              148
# Higher Education                                                        131
# Insurance                                                                54
# Advertising Services                                                     53
# Wholesale                                                                24
# Oil & Gas                                                                15
# Legal Services                                                            8
# Name: Industry, dtype: int64

# %%
country_grp["CompTotal"].median().loc["Germany"]
# Out:
# 70000.0

# %%
country_grp["CompTotal"].agg(['median','mean']).loc['Canada']
# Out:
# median    1.200000e+05
# mean      4.734850e+11
# Name: Canada, dtype: float64

# %%
filt = df["Country"]=="Algeria"
df.loc[filt]["LanguageHaveWorkedWith"].str.contains("Python").sum()
# Out:
# 35

# %%
con_uses_python = country_grp["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains("Python").sum())
con_uses_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
con_respondents = df["Country"].value_counts()
con_respondents
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 185, dtype: int64

# %%
python_df = pd.concat([con_respondents, con_uses_python], axis='columns' )
python_df
# Out:
#                                                     Country  \
# United States of America                              18647
# Germany                                                7328
# India                                                  5625
# United Kingdom of Great Britain and Northern Ir...     5552
# Canada                                                 3507
# ...                                                     ...
# Grenada                                                   1
# Guinea-Bissau                                             1
# Liechtenstein                                             1
# Marshall Islands                                          1
# Saint Kitts and Nevis                                     1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
python_df.rename(columns = {"Country":"NumRespondents","LanguageHaveWorkedWith":"NumKnowsPython"},inplace=True)
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     18647
# Germany                                                       7328
# India                                                         5625
# United Kingdom of Great Britain and Northern Ir...            5552
# Canada                                                        3507
# ...                                                            ...
# Grenada                                                          1
# Guinea-Bissau                                                    1
# Liechtenstein                                                    1
# Marshall Islands                                                 1
# Saint Kitts and Nevis                                            1
#
#                                                     NumKnowsPython
# United States of America                                     10062
# ...

# %%
python_df["PctKnowPython"] = (python_df["NumRespondents"]/python_df["NumKnowsPython"]) * 100
python_df.head(10)
# Out:
#                                                     NumRespondents  \
# United States of America                                     18647
# Germany                                                       7328
# India                                                         5625
# United Kingdom of Great Britain and Northern Ir...            5552
# Canada                                                        3507
# France                                                        2933
# Poland                                                        2435
# Netherlands                                                   2383
# Australia                                                     2078
# Brazil                                                        2042
#
#                                                     NumKnowsPython  \
# United States of America                                     10062
# Germany                                                       3686
# ...

# %%
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     18647
# Germany                                                       7328
# India                                                         5625
# United Kingdom of Great Britain and Northern Ir...            5552
# Canada                                                        3507
# ...                                                            ...
# Grenada                                                          1
# Guinea-Bissau                                                    1
# Liechtenstein                                                    1
# Marshall Islands                                                 1
# Saint Kitts and Nevis                                            1
#
#                                                     NumKnowsPython  \
# United States of America                                     10062
# ...

# %%
python_df.sort_values(by="PctKnowPython",ascending=False,inplace=True)
python_df.head(15)
# Out:
#                                        NumRespondents  NumKnowsPython  \
# Saint Kitts and Nevis                               1               0
# Gabon                                               2               0
# Niger                                               4               0
# Suriname                                            4               0
# Bahamas                                             2               0
# Guinea                                              2               0
# Monaco                                              2               0
# Djibouti                                            2               0
# Democratic People's Republic of Korea               2               0
# Central African Republic                            1               0
# Guinea-Bissau                                       1               0
# Marshall Islands                                    1               0
# ...

# %%
python_df.loc["Japan"]
# Out:
# NumRespondents    362.000000
# NumKnowsPython    188.000000
# PctKnowPython     192.553191
# Name: Japan, dtype: float64

# %% [markdown]
# # Cleaning data and Handling missing values

# %%
df.dropna(axis='index', how='all')
# Out:
#        ResponseId     Q120                      MainBranch                Age  \
# 67793       67794  I agree  I am a developer by profession    18-24 years old
# 59005       59006  I agree  I am a developer by profession    35-44 years old
# 61075       61076  I agree  I am a developer by profession    18-24 years old
# 2641         2642  I agree  I am a developer by profession    35-44 years old
# 37955       37956  I agree  I am a developer by profession    18-24 years old
# ...           ...      ...                             ...                ...
# 88820       88821  I agree                   None of these    35-44 years old
# 88828       88829  I agree                   None of these    25-34 years old
# 88830       88831  I agree                   None of these    18-24 years old
# 89028       89029  I agree                   None of these    45-54 years old
# 89159       89160  I agree                   None of these  Prefer not to say
#
# ...

# %%
df.isna()
# Out:
#        ResponseId   Q120  MainBranch    Age  Employment  RemoteWork  \
# 67793       False  False       False  False       False       False
# 59005       False  False       False  False       False       False
# 61075       False  False       False  False       False       False
# 2641        False  False       False  False       False       False
# 37955       False  False       False  False       False       False
# ...           ...    ...         ...    ...         ...         ...
# 88820       False  False       False  False        True        True
# 88828       False  False       False  False        True        True
# 88830       False  False       False  False        True        True
# 89028       False  False       False  False        True        True
# 89159       False  False       False  False        True        True
#
#        CodingActivities  EdLevel  LearnCode  LearnCodeOnline  \
# 67793             False    False      False             True
# ...

# %%
df.fillna("Missing")
# Out:
#        ResponseId     Q120                      MainBranch                Age  \
# 67793       67794  I agree  I am a developer by profession    18-24 years old
# 59005       59006  I agree  I am a developer by profession    35-44 years old
# 61075       61076  I agree  I am a developer by profession    18-24 years old
# 2641         2642  I agree  I am a developer by profession    35-44 years old
# 37955       37956  I agree  I am a developer by profession    18-24 years old
# ...           ...      ...                             ...                ...
# 88820       88821  I agree                   None of these    35-44 years old
# 88828       88829  I agree                   None of these    25-34 years old
# 88830       88831  I agree                   None of these    18-24 years old
# 89028       89029  I agree                   None of these    45-54 years old
# 89159       89160  I agree                   None of these  Prefer not to say
#
# ...

# %%
df["CompTotal"].mean().astype(int)
# Out:
# -9223372036854775808

# %% [markdown]
# # Date and Time

# %%
dft = pd.read_csv("ETH_1h.csv")
dft
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
dft["Date"] = pd.to_datetime(dft["Date"],format="%Y-%m-%d %I-%p")
dft
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
dft.loc[0,"Date"].day_name()
# Out:
# 'Friday'

# %%
dft["DayOfWeek"] = dft["Date"].dt.day_name()

# %%
dft
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
filt = (dft["Date"] < pd.to_datetime('2020-03-13')) & (dft["Date"] > pd.to_datetime('2020-02-13'))

# %%
dft.loc[filt]
# Out:
#                    Date  Symbol    Open    High     Low   Close       Volume  \
# 21  2020-03-12 23:00:00  ETHUSD  126.78  126.82  101.22  110.30  19338895.12
# 22  2020-03-12 22:00:00  ETHUSD  130.30  134.25  124.83  126.78   8822759.15
# 23  2020-03-12 21:00:00  ETHUSD  128.15  132.14  122.83  130.30   6500631.29
# 24  2020-03-12 20:00:00  ETHUSD  138.00  138.96  124.04  128.15  19731142.71
# 25  2020-03-12 19:00:00  ETHUSD  137.04  139.69  136.43  138.00   3815314.09
# ..                  ...     ...     ...     ...     ...     ...          ...
# 711 2020-02-13 05:00:00  ETHUSD  270.09  272.81  270.01  272.81   1069297.37
# 712 2020-02-13 04:00:00  ETHUSD  269.59  272.19  269.51  270.09   1298290.13
# 713 2020-02-13 03:00:00  ETHUSD  273.01  273.90  268.19  269.59   3038218.68
# 714 2020-02-13 02:00:00  ETHUSD  274.57  275.00  271.00  273.01   3175414.45
# 715 2020-02-13 01:00:00  ETHUSD  272.70  275.00  270.09  274.57   3924086.08
#
#     DayOfWeek
# 21   Thursday
# ...

# %%
dft.set_index('Date',inplace=True)

# %%
dft
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
highs = dft['High'].resample('D').max()

# %%
highs
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
# %matplotlib inline

# %%
dft['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # JSON, CSV, SQL

# %%
filt = df['Country']=='Germany'

# %%
df_ger = df.loc[filt].head(2)

# %%
df_ger.to_json('data_modified.json',orient='records')

# %%
pip install mysql.connector

# %%
pip install mysql-connector

# %%
import mysql.connector

# Replace these values with your MySQL server credentials and database name
host = "127.0.0.1"
user = "root"
password = ""
database = "staff_asia"
port = 3306

# Establish a connection to the MySQL server
try:
    connection = mysql.connector.connect(
        host=host,
        port=port,
        user=user,
        password=password,
        database=database
    )
    if connection.is_connected():
        print("Connected to MySQL database")

    # Now you can execute your SQL queries using `connection.cursor()`
    # For example:
    cursor = connection.cursor()
    cursor.execute("SELECT * FROM employee")
    rows = cursor.fetchall()
    for row in rows:
        print(row)

except mysql.connector.Error as error:
    print("Error: ", error)

finally:
    # Close the connection outside the try-except block
    if 'connection' in locals() and connection.is_connected():
        connection.close()
        print("MySQL connection is closed")
# Out:
# Connected to MySQL database
# ('180', 'Nurul', 'Data analyst', 'RD')
# ('188', 'Fahim', 'Data analyst', 'RD')
# MySQL connection is closed
